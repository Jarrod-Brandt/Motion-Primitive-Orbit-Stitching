# %% [markdown]
# # Introduction

# %% [markdown]
# ## To Do

# %% [markdown]
# 1. Construct a motion primitive library that summarizes the characteristics of arcs
# that exist within segments of the solution space.
# 2. Construct a motion primitive graph that discretely approximates a subset of the
# continuous solution space.
# 3. Search the graph for motion primitive sequences that serve as candidates for initial
# guesses for trajectories.
# 4. Construct an initial guess for each trajectory by refining each motion primitive
# sequence.
# 5. Correct each initial guess to produce a continuous trajectory with impulsive
# maneuvers using direct collocation and local optimization.
# 6. Compute additional transfers spanning segments of the design space.

# %% [markdown]
# # Initialization

# %% [markdown]
# ## Imports

# %%
import sys
import os
import random
import math

import numpy as np 
from numpy import cos, sin
import matplotlib
import matplotlib.pyplot as plt
import plotly.figure_factory as ff
import plotly.graph_objects as go

import pickle as pkl
import PIL.Image as Image



from PIL import Image
import copy
import seaborn as sns
from scipy.integrate import odeint
from scipy.integrate import solve_ivp


import gym
from gym import Env, spaces
import time
import operator



from datetime import datetime
import navpy as nav


from poliastro.bodies import Sun, Earth, Moon
from poliastro.ephem import Ephem
from poliastro.frames import Planes
from poliastro.plotting import StaticOrbitPlotter
from poliastro.plotting.misc import plot_solar_system
from poliastro.twobody import Orbit
from poliastro.util import norm, time_range
from poliastro.constants import J2000
from poliastro.plotting import OrbitPlotter3D
from poliastro.plotting import OrbitPlotter2D
from poliastro.twobody.sampling import EpochsArray, TrueAnomalyBounds, EpochBounds
from poliastro.maneuver import Maneuver
from poliastro.twobody.propagation import propagate, cowell
from poliastro import constants



from astropy import units as u
from astropy.time import Time, TimeDelta
from astropy.utils.data import conf
from astropy.coordinates import solar_system_ephemeris, EarthLocation
from astropy.coordinates import get_body_barycentric, get_body

from astroquery.jplhorizons import Horizons

conf.dataurl
conf.remote_timeout = 10000
solar_system_ephemeris.set("jpl")

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T
from torch.autograd import Variable
from torch.distributions import Normal
from torch.autograd import gradcheck
import torch.nn.init as init
from torch.nn.utils import clip_grad_norm_, clip_grad_value_

from captum.attr import LayerIntegratedGradients
from captum.attr import Saliency
from torchviz import make_dot


from IPython.display import clear_output
import time

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Two Body Problem (2BP)

# %% [markdown]
# ## Construct Motion Primitive Library

# %% [markdown]
# ## Construct Motion Primitive Graph

# %% [markdown]
# ## Identify Candidate Motion Primitive Sequences

# %% [markdown]
# ## Construct an Initial Guess from a Primitive Sequence

# %% [markdown]
# ## Recover a Continuous Trajectory

# %% [markdown]
# ## Explore the Transfer Design Space

# %% [markdown]
# # Circular Restricted Three Body Problem (CR3BP)

# %%
#Define constants
G = 6.67430e-11  # Gravitational constant (m^3/kg/s^2)
earth_mass = 5.972e24  # kg
moon_mass = 7.34767309e22  # kg
distance_earth_moon = 384400 * 1e3  # m
#Spacecraft Initial Conditions
x_0 = [0, 6469.77, 1733.57] << u.km
x_dot_0 = [8.27203, 6.56685, 2.38082] << u.km/u.s

dt_s = 60
dt_jd = dt_s / 86400

jd_0 = 2458974.0
#Moon ephemerides
t = Time([jd_0, jd_0 + 3], format='jd')
obj = Horizons(id='301', location='301', epochs=jd_0)  # '301' is the code for the Moon, '@0' is Earth's center

eph = obj.vectors()
print(eph['x'].value)

rm = [eph['x'].value[0], eph['y'].value[0], eph['z'].value[0]]
vm = [eph['vx'].value[0], eph['vy'].value[0], eph['vz'].value[0]]
rm = [coord * 149597870.7 for coord in rm]
print(rm)
print(vm)
#DCM from ECI to MFR frames
# Out:
# [-0.002432640947712431]
# [-363917.9059554097, -16865.118088576455, 27333.349310997128]
# [-4.460617541043693e-05, -0.0007768412277023055, 6.157411917581093e-05]

# %%
def get_moon_ephem(t):
    obj = Horizons(id='301', location='301', epochs=t)  # '301' is the code for the Moon, '@0' is Earth's center
    eph = obj.vectors()

    rm = []
    rm_m = []
    for n in range(0,len(eph)):
        rs = [eph['x'].value[n], eph['y'].value[n], eph['z'].value[n]]
        rs = [coord * 149597870.7 for coord in rs]
        rm_m.append(np.linalg.norm(rs))
        rm.append(rs)
    
    return np.array(rm), np.array(rm_m)

# %%
jd_0 = 2458974.0
jd_f = jd_0 + 28
#Moon ephemerides

t = np.linspace(jd_0, jd_f, 75).tolist()

rm, rm_m = get_moon_ephem(t)

plt.plot(rm[:,0], rm[:,1])

# %%
def lunar_DEQ(t, x):
    mu_earth = 398600.4

    #Extract the position components from the state vector
    X = x[0]
    Y = x[1]
    Z = x[2]

    r_ = np.array([X, Y, Z])
    r = np.linalg.norm(r_)

    #Extract the velocities from the state vector
    vX = x[3]
    vY = x[4]
    vZ = x[5]

    a_earth = -mu_earth*r_/r**3

    dxdt = [vX, vY, vZ, a_earth[0],a_earth[1],a_earth[2]]
    
    return dxdt

t_span = (0, 2551520)
t = np.linspace(t_span[0], t_span[1], num=100000)

x_0 = np.array([-383781, 0, 0, 0, 1.022, 0])
# y = odeint(lunar_DEQ, x_0,t)
sol = solve_ivp(lunar_DEQ, t_span, x_0,t_eval=t, dense_output='True', rtol=1e-10, atol=1e-10 )



x = sol.y[0,:]
y = sol.y[1,:]

plt.plot(x, y)
plt.plot(rm[:,0], rm[:,1])

# %%
plt.plot(t, rm_m)
print(min(rm_m))
print(max(rm_m))
# Out:
# 357160.791786202
# 409950.89485697466

# %%
#Use Curtis book to formulate motion in earth-moon co-rotating frame

#non-dimensionalize plots/data
#Plot trajectories
#Vary initial conditions, try to match variance wth paper
#Perform stability analysis

# %% [markdown]
# ## Construct Motion Primitive Library

# %% [markdown]
# ## Construct Motion Primitive Graph

# %% [markdown]
# ## Identify Candidate Motion Primitive Sequences

# %% [markdown]
# ## Construct an Initial Guess from a Primitive Sequence

# %% [markdown]
# ## Recover a Continuous Trajectory

# %% [markdown]
# ## Explore the Transfer Design Space
